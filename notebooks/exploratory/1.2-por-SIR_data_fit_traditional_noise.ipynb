# %% [markdown]
# # Data Fit (traditional optimization methods): SIR data with little noise

# %% [markdown]
# On this notebook, we will use traditional optimization models in order to fit the SIR model on data with little noise. The main goal is to obtain the following parameters:
#
# - $\beta$: Contact rate
# - $\gamma$: Mean recovery rate
#
# The optimization models used for fitting data are the followings:

# %% [markdown]
# ## Load data

# %%
# Load Path
import pickle as pkl
data_path = '../../data/raw/simulated/SIR'
with open(f'{data_path}/sir.pkl', 'rb') as f:
    data_sim = pkl.load(f)

# %% [markdown]
# ## Division Training/Validation/Test
#
# Only Test will be used. Given the big ammount of simulations, only 1% will be used as test initially.
#
# ### Adding Gaussian Noise to the Simulated Infected Curves
#
# To make the parameter estimation task more realistic, we add a small amount of Gaussian noise to the infected time series generated by the SIR model. This simulates observational noise typically found in real-world data (e.g., due to reporting errors or measurement variability).
#
# The noise is generated using a normal distribution with zero mean and a standard deviation equal to the mean value of the infected curve.
#
# Mathematically, for each infected curve $I(t)$, the noisy version is:
#
#
# $$I_{\text{noisy}}(t) = I(t) + \mathcal{N}(0, \sigma), \quad \text{where} \quad \sigma = \text{mean}(I(t))$$
#
# Values below zero are clipped to avoid unrealistic negative infection counts.

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# Prepare data
X = []  # X will be the data from infected people
y = []  # y will be the parameters from that simulation
times = []  # Times for each simulation

for simulation in data_sim:
    compartment_data = simulation[0]  # S, I, R matrix
    parameters = simulation[2]  # [beta, gamma]
    time_steps = simulation[1]  # Times
    
    # Extract I values
    I_values = compartment_data[:, 1]  # Second column (I compartment)
    
    # Add Gaussian noise
    noise_std = np.mean(I_values)  # mean value
    noise = np.random.normal(0, noise_std, size=I_values.shape)
    I_noisy = I_values + noise
    
    
    X.append(I_noisy)  # Add to the characteristic list
    y.append(parameters)  # Add to label list
    times.append(time_steps)  # Add times for each simulation

# Convert to numpy arrays
X = np.array(X)
y = np.array(y)
times = np.array(times)

# First division: 99% training + validation, 1% test
_, X_test, _, y_test, _, ts_test = train_test_split(X, y, times, test_size=0.01, random_state=42)

# Print shapes to verify
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
print("ts_test shape:", ts_test.shape)
# Out:
# X_test shape: (1000, 1001)
# y_test shape: (1000, 2)
# ts_test shape: (1000, 1001)

# %% [markdown]
# ## Fitting with data

# %% [markdown]
# Using scipy optimize minimize. Defining functions for traditional methods

# %%
import numpy as np
from summer import CompartmentalModel
from scipy.optimize import minimize

# Function to simulate the SIR model given beta and gamma
def simulate_SIR(beta, gamma, times=[0, 100], S0=90, I0=10):
    model = CompartmentalModel(
        times=times,
        compartments=["S", "I", "R"],
        infectious_compartments=["I"],
        timestep=0.1,
    )
    model.set_initial_population(distribution={"S": S0, "I": I0})
    model.add_infection_frequency_flow("infection", contact_rate=beta, source="S", dest="I")
    model.add_transition_flow("recovery", fractional_rate=gamma, source="I", dest="R")
    model.run()
    return model.outputs.T[1] # Infected compartment

# Objective function to minimize (MSE between observed and simulated I curve)
def mse(params, I_obs):
    beta, gamma = params
    I_sim = simulate_SIR(beta, gamma)
    return np.mean((I_sim - I_obs)**2)

# Fitting function for a given I_obs curve
def fit_SIR(I_obs, objective, method= 'L-BFGS-B', beta_bounds=(0.1, 3), gamma_bounds=(0.1, 1)):
    # Random initialization within bounds
    beta_init = np.random.uniform(*beta_bounds)
    gamma_init = np.random.uniform(*gamma_bounds)

    res = minimize(
        objective,
        x0=[beta_init, gamma_init],
        args=(I_obs),
        bounds=[beta_bounds, gamma_bounds],
        method=method,
    )
    return res.x, res.fun  # (beta_hat, gamma_hat), loss

# Example usage:
# Suppose you have an I_obs curve generated using summer
# beta_hat, gamma_hat = fit_SIR(outputs["I"], times)

# %% [markdown]
# ## Fit with optimizer L-BFGS-B and MSE objective function

# %%
# %%time

import time
# Start total timer
start_total = time.time()

params_fit = []
y_pred = []

for i, (infected, params) in enumerate(zip(X_test, y_test)):
    print("Fitting simulation", i)
    
    # Start iteration timer
    start_iter = time.time()

    # Fit model to I_obs using fit_SIR (uses random initialization internally)
    (beta_fit, gamma_fit), loss = fit_SIR(I_obs=infected, objective=mse)
    beta_real, gamma_real = params

    # End iteration timer
    end_iter = time.time()
    elapsed_iter = end_iter - start_iter
    elapsed_total = end_iter - start_total


    # Log comparison
    print("Fitted params:", beta_fit, gamma_fit)
    print("Real params:", beta_real, gamma_real)
    print(f"Iteration time: {elapsed_iter:.2f} seconds")
    print(f"Total time so far: {elapsed_total:.2f} seconds\n")

    # Store results
    
    y_pred.append([beta_fit, gamma_fit])
    params_fit.append([i, elapsed_iter, beta_real, beta_fit, gamma_real, gamma_fit])
    
print(f"\nFinal total time elapsed: {time.time() - start_total:.2f} seconds")
# Out:
# Fitting simulation 0
# Fitted params: 0.8029157598177786 0.5342260256186323
# Real params: 0.7913167201961155 0.5296031637984128
# Iteration time: 3.29 seconds
# Total time so far: 3.29 seconds
#
# Fitting simulation 1
# Fitted params: 0.2850461517080144 0.1680845919819159
# Real params: 0.28326233774501636 0.167902579458222
# Iteration time: 2.25 seconds
# Total time so far: 5.54 seconds
#
# Fitting simulation 2
# Fitted params: 2.3755890930165116 0.8428653117056358
# Real params: 2.3430954897977716 0.8434677440691575
# Iteration time: 1.37 seconds
# Total time so far: 6.91 seconds
#
# Fitting simulation 3
# Fitted params: 2.413038227228111 0.40265412258963085
# Real params: 2.443757211976645 0.4005552103722785
# Iteration time: 5.80 seconds
# Total time so far: 12.71 seconds
#
# Fitting simulation 4
# Fitted params: 0.8790629318694452 0.21759793948365763
# Real params: 0.9035563609752326 0.21629190806137705
# Iteration time: 1.73 seconds
# Total time so far: 14.45 seconds
#
# Fitting simulation 5
# Fitted params: 0.9034614305366147 0.8588617584651898
# Real params: 0.9069045877482117 0.8596003211037689
# Iteration time: 1.98 seconds
# Total time so far: 16.42 seconds
#
# Fitting simulation 6
# Fitted params: 1.991712965942269 0.7664881874982534
# Real params: 2.000490325853977 0.7585103863659454
# Iteration time: 2.76 seconds
# Total time so far: 19.18 seconds
#
# Fitting simulation 7
# Fitted params: 2.2667219497582702 0.7501464733568258
# Real params: 2.2467350580031926 0.7445448908716122
# Iteration time: 1.28 seconds
# Total time so far: 20.45 seconds
#
# Fitting simulation 8
# Fitted params: 2.4332906765131948 0.4190500134822671
# Real params: 2.4515757567335474 0.4224810666180411
# Iteration time: 1.66 seconds
# Total time so far: 22.12 seconds
#
# Fitting simulation 9
# Fitted params: 0.6187854801223297 0.5342723767226282
# Real params: 0.6275514518434108 0.5379642390962294
# Iteration time: 1.45 seconds
# Total time so far: 23.56 seconds
#
# Fitting simulation 10
# Fitted params: 2.9521607680858684 0.13021644617336478
# Real params: 2.9204180928360666 0.13138197029742887
# Iteration time: 1.14 seconds
# Total time so far: 24.71 seconds
#
# Fitting simulation 11
# Fitted params: 1.2141753569710534 0.5141552330308526
# Real params: 1.2184571431087925 0.5171403582002593
# Iteration time: 1.22 seconds
# Total time so far: 25.93 seconds
#
# Fitting simulation 12
# Fitted params: 2.3596502019287167 0.1437538631937279
# Real params: 2.2814256179423174 0.14610782946728168
# Iteration time: 1.67 seconds
# Total time so far: 27.60 seconds
#
# Fitting simulation 13
# Fitted params: 1.1094870822830563 0.7252565227226708
# Real params: 1.1106365099134086 0.7219152557776841
# Iteration time: 1.26 seconds
# Total time so far: 28.86 seconds
#
# Fitting simulation 14
# Fitted params: 2.7335349717014594 0.563943456748807
# Real params: 2.787261705846991 0.5625620185748752
# Iteration time: 1.57 seconds
# Total time so far: 30.43 seconds
#
# Fitting simulation 15
# Fitted params: 2.646464453736683 0.7869922363450623
# Real params: 2.6245029809590097 0.7837822483016668
# Iteration time: 1.28 seconds
# Total time so far: 31.71 seconds
#
# Fitting simulation 16
# Fitted params: 0.9138429104551568 0.6970195470031875
# Real params: 0.9080747462861731 0.6873232728349091
# Iteration time: 2.29 seconds
# Total time so far: 34.00 seconds
#
# Fitting simulation 17
# Fitted params: 2.5584698305976317 0.6029158061051807
# Real params: 2.548635539944886 0.5986643084971042
# Iteration time: 1.42 seconds
# Total time so far: 35.42 seconds
#
# Fitting simulation 18
# Fitted params: 2.2783023369318944 0.21251434211158085
# Real params: 2.3780695880974974 0.21526584157546774
# Iteration time: 1.85 seconds
# Total time so far: 37.27 seconds
#
# Fitting simulation 19
# Fitted params: 1.6340738940225352 0.9762722894903132
# Real params: 1.6440900972625445 0.9806176619190662
# Iteration time: 1.82 seconds
# Total time so far: 39.08 seconds
#
# Fitting simulation 20
# Fitted params: 0.6040000633478079 0.3309754391090972
# Real params: 0.6025440098745803 0.3309879904324804
# Iteration time: 2.08 seconds
# Total time so far: 41.17 seconds
#
# Fitting simulation 21
# Fitted params: 1.5275943159972403 0.9243237997306692
# Real params: 1.5277438920034276 0.9251670171566236
# Iteration time: 1.57 seconds
# Total time so far: 42.74 seconds
#
# Fitting simulation 22
# Fitted params: 1.402698470315985 0.4491600969599171
# Real params: 1.3870598111896784 0.4429982496414083
# Iteration time: 1.17 seconds
# Total time so far: 43.91 seconds
#
# Fitting simulation 23
# Fitted params: 1.5971229417744468 0.7018800304203733
# Real params: 1.6131758234731697 0.7107008526314073
# Iteration time: 1.39 seconds
# Total time so far: 45.29 seconds
#
# Fitting simulation 24
# Fitted params: 0.22720545737954517 0.9820016868870649
# Real params: 0.23986487428522785 0.9813914914459176
# Iteration time: 1.00 seconds
# Total time so far: 46.30 seconds
#
# Fitting simulation 25
# Fitted params: 2.8362685026523913 0.8404958947481188
# Real params: 2.8452523089233623 0.8417541644261641
# Iteration time: 1.47 seconds
# Total time so far: 47.77 seconds
#
# Fitting simulation 26
# Fitted params: 1.1309368976412622 0.29507701727571534
# Real params: 1.1246354211813685 0.29718610463516726
# Iteration time: 2.07 seconds
# Total time so far: 49.84 seconds
#
# Fitting simulation 27
# Fitted params: 0.3574099296756704 0.8540446642729494
# Real params: 0.4170357085763634 0.9108297586170683
# Iteration time: 1.79 seconds
# Total time so far: 51.63 seconds
#
# Fitting simulation 28
# Fitted params: 1.4623542347696006 0.43937621872765714
# Real params: 1.4772904440546004 0.4363137178224886
# Iteration time: 1.23 seconds
# Total time so far: 52.87 seconds
#
# Fitting simulation 29
# Fitted params: 2.7178814419135064 0.8570392620179855
# Real params: 2.699653636676464 0.8596957938390025
# Iteration time: 0.92 seconds
# Total time so far: 53.78 seconds
#
# Fitting simulation 30
# Fitted params: 2.814357792688533 0.4794516572573571
# Real params: 2.8105181819533507 0.4813969363796865
# Iteration time: 1.55 seconds
# Total time so far: 55.33 seconds
#
# Fitting simulation 31
# Fitted params: 0.541374113831384 0.4582309264735702
# Real params: 0.5444957244056743 0.46053856934215887
# Iteration time: 2.30 seconds
# Total time so far: 57.64 seconds
#
# Fitting simulation 32
# Fitted params: 1.6149766786585689 0.6546441738866552
# Real params: 1.6295790321175576 0.6564539096142817
# Iteration time: 1.52 seconds
# Total time so far: 59.15 seconds
#
# Fitting simulation 33
# Fitted params: 1.5960263380017907 0.8062022329390308
# Real params: 1.6119862686669988 0.8124096647714173
# Iteration time: 1.47 seconds
# Total time so far: 60.63 seconds
#
# Fitting simulation 34
# Fitted params: 1.8221528915833243 0.543788593286415
# Real params: 1.8230621378509893 0.5544453909140643
# Iteration time: 1.13 seconds
# Total time so far: 61.76 seconds
#
# Fitting simulation 35
# Fitted params: 2.3203753121822186 0.6028934282044427
# Real params: 2.2997172546560534 0.5893159422040833
# Iteration time: 1.56 seconds
# Total time so far: 63.32 seconds
#
# Fitting simulation 36
# Fitted params: 1.2480637953696188 0.6377514429060253
# Real params: 1.2395818606461524 0.6309499017720106
# Iteration time: 1.38 seconds
# Total time so far: 64.70 seconds
#
# Fitting simulation 37
# Fitted params: 1.8087543653124656 0.5846084614125056
# Real params: 1.811734759253114 0.5861952434366674
# Iteration time: 1.26 seconds
# Total time so far: 65.96 seconds
#
# Fitting simulation 38
# Fitted params: 0.11785810906288424 0.41842868070000155
# Real params: 0.2654350294583385 0.5430991595442936
# Iteration time: 3.25 seconds
# Total time so far: 69.21 seconds
#
# Fitting simulation 39
# Fitted params: 2.278988289439666 0.6594239513883234
# Real params: 2.264480756897826 0.6583981253479592
# Iteration time: 1.36 seconds
# Total time so far: 70.57 seconds
#
# Fitting simulation 40
# Fitted params: 1.5083516576989442 0.3622122185238515
# Real params: 1.5420375162505673 0.3608934746120165
# Iteration time: 1.36 seconds
# Total time so far: 71.93 seconds
#
# Fitting simulation 41
# Fitted params: 2.9377500967441335 0.5952639017407909
# Real params: 2.912367175611042 0.5947630705342855
# Iteration time: 1.21 seconds
# Total time so far: 73.14 seconds
#
# Fitting simulation 42
# Fitted params: 0.8848746633751742 0.6784480393390999
# Real params: 0.9042726229469189 0.6879170232200276
# Iteration time: 1.27 seconds
# Total time so far: 74.41 seconds
#
# Fitting simulation 43
# Fitted params: 0.12380525100940822 0.743322384170759
# Real params: 0.3764449592117617 0.9650464744651742
# Iteration time: 2.46 seconds
# Total time so far: 76.87 seconds
#
# Fitting simulation 44
# Fitted params: 0.10049511365109691 0.32390100966209845
# Real params: 0.2213590401605095 0.429271187815636
# Iteration time: 3.85 seconds
# Total time so far: 80.72 seconds
#
# Fitting simulation 45
# Fitted params: 2.5249164097873393 0.5454588605235415
# Real params: 2.5023670468811985 0.546314701054407
# Iteration time: 2.12 seconds
# Total time so far: 82.84 seconds
#
# Fitting simulation 46
# Fitted params: 1.8408959511095475 0.4081230902730569
# Real params: 1.8604080037907378 0.40459809128187896
# Iteration time: 1.46 seconds
# Total time so far: 84.30 seconds
#
# Fitting simulation 47
# Fitted params: 2.9458107554814683 0.15706350445768605
# Real params: 2.979774660155671 0.15980071636894766
# Iteration time: 6.13 seconds
# Total time so far: 90.43 seconds
#
# Fitting simulation 48
# Fitted params: 2.5437089206226684 0.2697048359723898
# Real params: 2.5472502925696943 0.2710150091927896
# Iteration time: 1.90 seconds
# Total time so far: 92.33 seconds
#
# Fitting simulation 49
# Fitted params: 1.057209538295644 0.8694481451262333
# Real params: 1.0585441495272954 0.8669877428236217
# Iteration time: 2.00 seconds
# Total time so far: 94.33 seconds
#
# Fitting simulation 50
# Fitted params: 2.0429631947508127 0.14272262931931406
# Real params: 1.9753886093503852 0.1404766313236042
# Iteration time: 0.99 seconds
# Total time so far: 95.32 seconds
#
# Fitting simulation 51
# Fitted params: 1.0217270709876562 1.0
# Real params: 1.012183683049737 0.9912890945517543
# Iteration time: 2.02 seconds
# Total time so far: 97.34 seconds
#
# Fitting simulation 52
# Fitted params: 2.9908510891259596 0.8921945045232303
# Real params: 2.9464720179563213 0.9023069730569342
# Iteration time: 1.47 seconds
# Total time so far: 98.82 seconds
#
# Fitting simulation 53
# Fitted params: 2.2947642554741052 0.1458438975841479
# Real params: 2.2347068396533025 0.1475152525589268
# Iteration time: 2.00 seconds
# Total time so far: 100.82 seconds
#
# Fitting simulation 54
# Fitted params: 1.617830762868455 1.0
# Real params: 1.6297400572072003 0.9966580395464606
# Iteration time: 1.66 seconds
# Total time so far: 102.48 seconds
#
# Fitting simulation 55
# Fitted params: 1.7752471709656081 0.7266483767192282
# Real params: 1.7764110851202064 0.7238735052880483
# Iteration time: 1.53 seconds
# Total time so far: 104.02 seconds
#
# Fitting simulation 56
# Fitted params: 0.6314361996010228 0.37850615596725856
# Real params: 0.6567575273067973 0.3890566177227548
# Iteration time: 1.66 seconds
# Total time so far: 105.67 seconds
#
# Fitting simulation 57
# Fitted params: 1.401373119125264 0.19158722736839742
# Real params: 1.4022727392782237 0.1887241789368022
# Iteration time: 1.89 seconds
# Total time so far: 107.56 seconds
#
# Fitting simulation 58
# Fitted params: 0.37533948530203654 0.1230556581939266
# Real params: 0.37112960589355515 0.1287940348861206
# Iteration time: 2.53 seconds
# Total time so far: 110.09 seconds
#
# Fitting simulation 59
# Fitted params: 2.890560612100412 0.22429105432616736
# Real params: 2.853609808607162 0.22398975244330321
# Iteration time: 1.76 seconds
# Total time so far: 111.85 seconds
#
# Fitting simulation 60
# Fitted params: 1.5324012046043063 0.3719900988279814
# Real params: 1.5294727217020108 0.3746044494796279
# Iteration time: 1.77 seconds
# Total time so far: 113.63 seconds
#
# Fitting simulation 61
# Fitted params: 1.087528516145309 0.7780599221623308
# Real params: 1.0938902519356046 0.777023335422136
# Iteration time: 1.22 seconds
# Total time so far: 114.85 seconds
#
# Fitting simulation 62
# Fitted params: 1.5206609453833029 0.8855323527428802
# Real params: 1.5378109373269508 0.8886044914025132
# Iteration time: 1.90 seconds
# Total time so far: 116.75 seconds
#
# Fitting simulation 63
# Fitted params: 1.019704076339126 0.11706179547190776
# Real params: 1.0366819839309145 0.11932190912572438
# Iteration time: 2.12 seconds
# Total time so far: 118.87 seconds
#
# Fitting simulation 64
# Fitted params: 0.6146143493270583 0.5696842700357797
# Real params: 0.6072425493582481 0.5644534763818941
# Iteration time: 2.00 seconds
# Total time so far: 120.87 seconds
#
# Fitting simulation 65
# Fitted params: 0.28804615707650927 0.9517918485159526
# Real params: 0.2925576080902705 0.958302366638218
# Iteration time: 1.08 seconds
# Total time so far: 121.95 seconds
#
# Fitting simulation 66
# Fitted params: 0.808336896127949 0.46481143299299243
# Real params: 0.7953380325555375 0.4601942676643005
# Iteration time: 2.35 seconds
# Total time so far: 124.30 seconds
#
# Fitting simulation 67
# Fitted params: 2.325299183193976 0.8745917285117142
# Real params: 2.338071931664265 0.8871763920717799
# Iteration time: 1.07 seconds
# Total time so far: 125.38 seconds
#
# Fitting simulation 68
# Fitted params: 0.7720060975102754 0.1314572576050767
# Real params: 0.7776728248019819 0.12930342966098743
# Iteration time: 1.41 seconds
# Total time so far: 126.79 seconds
#
# Fitting simulation 69
# Fitted params: 0.5164274848474831 0.9053518755049603
# Real params: 0.1373956586179887 0.580172114682211
# Iteration time: 1.96 seconds
# Total time so far: 128.76 seconds
#
# Fitting simulation 70
# Fitted params: 1.5179352101816608 0.5740924049174515
# Real params: 1.5271372499306608 0.5769525468745765
# Iteration time: 0.94 seconds
# Total time so far: 129.70 seconds
#
# Fitting simulation 71
# Fitted params: 2.5791850898150015 0.14107413627117757
# Real params: 2.5047719089742753 0.1436203876551376
# Iteration time: 9.03 seconds
# Total time so far: 138.73 seconds
#
# Fitting simulation 72
# Fitted params: 0.3227773118629971 0.7744111147639242
# Real params: 0.1601097180694349 0.6308263020401549
# Iteration time: 2.04 seconds
# Total time so far: 140.77 seconds
#
# Fitting simulation 73
# Fitted params: 2.9812437181226277 0.6419911436197655
# Real params: 2.9490973354365164 0.646528684931702
# Iteration time: 1.63 seconds
# Total time so far: 142.40 seconds
#
# Fitting simulation 74
# Fitted params: 0.49508140735549555 0.3901447073329141
# Real params: 0.4766891962663907 0.37739858666134485
# Iteration time: 1.80 seconds
# Total time so far: 144.20 seconds
#
# Fitting simulation 75
# Fitted params: 0.7713670032921249 0.4617414698270526
# Real params: 0.7726928192967245 0.4616079686144626
# Iteration time: 2.02 seconds
# Total time so far: 146.22 seconds
#
# Fitting simulation 76
# Fitted params: 1.3385964614564503 0.5400539237007879
# Real params: 1.3216820603692685 0.5334321429123662
# Iteration time: 1.74 seconds
# Total time so far: 147.96 seconds
#
# Fitting simulation 77
# Fitted params: 1.0209928338339673 0.8748307968670802
# Real params: 1.036748912339577 0.8869044290174568
# Iteration time: 1.90 seconds
# Total time so far: 149.86 seconds
#
# Fitting simulation 78
# Fitted params: 2.306630691733569 0.30592010702449535
# Real params: 2.285110486323239 0.304490388363963
# Iteration time: 1.27 seconds
# Total time so far: 151.13 seconds
#
# Fitting simulation 79
# Fitted params: 0.18249867531690953 0.7824661784455886
# Real params: 0.31736469816480617 0.9025384856438501
# Iteration time: 2.65 seconds
# Total time so far: 153.78 seconds
#
# Fitting simulation 80
# Fitted params: 2.9348915405494114 0.20244047164341705
# Real params: 2.8381904826928146 0.20379141098084935
# Iteration time: 1.89 seconds
# Total time so far: 155.67 seconds
#
# Fitting simulation 81
# Fitted params: 0.40749793164137366 0.825177485831384
# Real params: 0.4579249997259025 0.8650154836752885
# Iteration time: 2.33 seconds
# Total time so far: 158.00 seconds
#
# Fitting simulation 82
# Fitted params: 2.7731338499260243 0.3827335004678969
# Real params: 2.733253781722821 0.374788406523219
# Iteration time: 1.17 seconds
# Total time so far: 159.17 seconds
#
# Fitting simulation 83
# Fitted params: 0.1 0.5681173648704629
# Real params: 0.15740043780758417 0.6226295130582703
# Iteration time: 2.75 seconds
# Total time so far: 161.92 seconds
#
# Fitting simulation 84
# Fitted params: 1.3115384085150288 0.48527810732516796
# Real params: 1.2973804324477665 0.4876943700905836
# Iteration time: 0.97 seconds
# Total time so far: 162.88 seconds
#
# Fitting simulation 85
# Fitted params: 0.8399772931774415 0.7249958027238799
# Real params: 0.8873400507062857 0.7508161238744493
# Iteration time: 1.46 seconds
# Total time so far: 164.34 seconds
#
# Fitting simulation 86
# Fitted params: 1.8930482628006526 0.272993837815134
# Real params: 1.9366129715857923 0.27506463709076845
# Iteration time: 1.49 seconds
# Total time so far: 165.83 seconds
#
# Fitting simulation 87
# Fitted params: 0.9715447503247263 0.527767846929778
# Real params: 0.9814753941105414 0.529415540590659
# Iteration time: 1.55 seconds
# Total time so far: 167.38 seconds
#
# Fitting simulation 88
# Fitted params: 1.5227361034049571 0.9115135852724139
# Real params: 1.5107706561037948 0.9043301238890638
# Iteration time: 1.08 seconds
# Total time so far: 168.45 seconds
#
# Fitting simulation 89
# Fitted params: 1.9235373738147479 0.9429094146098761
# Real params: 1.9189058344863956 0.9510184303016177
# Iteration time: 1.37 seconds
# Total time so far: 169.82 seconds
#
# Fitting simulation 90
# Fitted params: 0.6870535962419871 0.7399513902492002
# Real params: 0.668338697966822 0.7336594543391174
# Iteration time: 1.55 seconds
# Total time so far: 171.37 seconds
#
# Fitting simulation 91
# Fitted params: 1.2452737420795776 0.33690956020049784
# Real params: 1.2536122178038078 0.33131351825630406
# Iteration time: 1.38 seconds
# Total time so far: 172.75 seconds
#
# Fitting simulation 92
# Fitted params: 1.2283582484058855 0.17246048220945825
# Real params: 1.1982029236657066 0.17105818498859815
# Iteration time: 1.69 seconds
# Total time so far: 174.43 seconds
#
# Fitting simulation 93
# Fitted params: 2.1972892853833437 0.2352210299011144
# Real params: 2.2408348260669926 0.22952386288307522
# Iteration time: 1.18 seconds
# Total time so far: 175.62 seconds
#
# Fitting simulation 94
# Fitted params: 0.10124111863409811 0.3631932747420218
# Real params: 0.35484243316106123 0.5702796485273598
# Iteration time: 2.73 seconds
# Total time so far: 178.35 seconds
#
# Fitting simulation 95
# Fitted params: 0.6183597469131022 0.45116781852075205
# Real params: 0.6507632345090368 0.46999680269699495
# Iteration time: 1.62 seconds
# Total time so far: 179.97 seconds
#
# Fitting simulation 96
# Fitted params: 2.3308629891144053 0.9833217022247116
# Real params: 2.38456907364799 0.9892702991687269
# Iteration time: 2.07 seconds
# Total time so far: 182.04 seconds
#
# Fitting simulation 97
# Fitted params: 2.419115668622026 0.43473196908394846
# Real params: 2.4076924540081546 0.43498466418487747
# Iteration time: 1.10 seconds
# Total time so far: 183.14 seconds
#
# Fitting simulation 98
# Fitted params: 0.42258995144722095 0.7464474096842019
# Real params: 0.30944256099097095 0.6581191809646451
# Iteration time: 2.34 seconds
# Total time so far: 185.48 seconds
#
# Fitting simulation 99
# Fitted params: 1.443052449169932 0.21278159376355782
# Real params: 1.4146061093331401 0.2125094506324965
# Iteration time: 1.22 seconds
# Total time so far: 186.70 seconds
#
# Fitting simulation 100
# Fitted params: 1.0140362847042168 0.5438065809707299
# Real params: 1.0154742228585552 0.5447438785815863
# Iteration time: 1.47 seconds
# Total time so far: 188.17 seconds
#
# Fitting simulation 101
# Fitted params: 0.6670989566489203 0.1784609215451218
# Real params: 0.6618465844593998 0.1783668218879289
# Iteration time: 1.79 seconds
# Total time so far: 189.96 seconds
#
# Fitting simulation 102
# Fitted params: 0.8845688042428825 0.24418467245488673
# Real params: 0.888171984853696 0.24790546588535034
# Iteration time: 1.39 seconds
# Total time so far: 191.36 seconds
#
# Fitting simulation 103
# Fitted params: 1.6057342668667998 0.3755721498017276
# Real params: 1.6259925913475544 0.3680247383677784
# Iteration time: 1.37 seconds
# Total time so far: 192.73 seconds
#
# Fitting simulation 104
# Fitted params: 0.6896760848857219 0.6774541020752815
# Real params: 0.6447434739462361 0.6560743326356155
# Iteration time: 1.48 seconds
# Total time so far: 194.22 seconds
#
# Fitting simulation 105
# Fitted params: 1.1955358471914042 0.3500193936318115
# Real params: 1.1797908866585551 0.34228886683955917
# Iteration time: 2.08 seconds
# Total time so far: 196.29 seconds
#
# Fitting simulation 106
# Fitted params: 0.10514950228274576 0.3153866822984642
# Real params: 0.17188616290697656 0.3786522992026118
# Iteration time: 2.66 seconds
# Total time so far: 198.95 seconds
#
# Fitting simulation 107
# Fitted params: 0.31726670369491716 0.7327584107971314
# Real params: 0.6320463365096605 0.9928504264001572
# Iteration time: 2.44 seconds
# Total time so far: 201.39 seconds
#
# Fitting simulation 108
# Fitted params: 1.3353307666286074 0.8176316885684838
# Real params: 1.327474273143673 0.8089986451228814
# Iteration time: 1.33 seconds
# Total time so far: 202.72 seconds
#
# Fitting simulation 109
# Fitted params: 0.3928166527050475 0.37946832398653824
# Real params: 0.39477246571846647 0.3763741638619731
# Iteration time: 4.56 seconds
# Total time so far: 207.28 seconds
#
# Fitting simulation 110
# Fitted params: 1.094221098308542 0.4381629220575538
# Real params: 1.1001739214825816 0.4435930266360718
# Iteration time: 1.70 seconds
# Total time so far: 208.98 seconds
#
# Fitting simulation 111
# Fitted params: 2.624770860448418 0.5676938049901579
# Real params: 2.607888884323128 0.5696682417955001
# Iteration time: 1.24 seconds
# Total time so far: 210.22 seconds
#
# Fitting simulation 112
# Fitted params: 2.146782979485151 0.12364592808981928
# Real params: 2.157844870512502 0.12134117996009955
# Iteration time: 1.71 seconds
# Total time so far: 211.93 seconds
#
# Fitting simulation 113
# Fitted params: 1.9134389315533193 0.745730490591602
# Real params: 1.9186579031231479 0.7447723866522294
# Iteration time: 1.08 seconds
# Total time so far: 213.01 seconds
#
# Fitting simulation 114
# Fitted params: 1.7273510604344935 0.9607283712011176
# Real params: 1.749777425502625 0.9708302345994667
# Iteration time: 1.07 seconds
# Total time so far: 214.08 seconds
#
# Fitting simulation 115
# Fitted params: 2.938158350969604 0.42683341183157
# Real params: 2.9307896264985356 0.4331145086477248
# Iteration time: 0.97 seconds
# Total time so far: 215.05 seconds
#
# Fitting simulation 116
# Fitted params: 0.2460326192885038 0.487891625117674
# Real params: 0.36278784451866497 0.583390311154955
# Iteration time: 2.60 seconds
# Total time so far: 217.66 seconds
#
# Fitting simulation 117
# Fitted params: 2.5889750438248464 0.40075060767018716
# Real params: 2.558298663657472 0.40110187734257663
# Iteration time: 1.77 seconds
# Total time so far: 219.43 seconds
#
# Fitting simulation 118
# Fitted params: 0.5322801878455837 0.5031674447673703
# Real params: 0.5392768278287965 0.5072902999756933
# Iteration time: 1.45 seconds
# Total time so far: 220.88 seconds
#
# Fitting simulation 119
# Fitted params: 2.5264409689451073 0.44106554030187267
# Real params: 2.502373093059172 0.4441370368339027
# Iteration time: 1.36 seconds
# Total time so far: 222.24 seconds
#
# Fitting simulation 120
# Fitted params: 1.85819564213583 0.42105751977962147
# Real params: 1.8347853107205527 0.41795068311848416
# Iteration time: 1.19 seconds
# Total time so far: 223.44 seconds
#
# Fitting simulation 121
# Fitted params: 2.835070218770008 0.6239164201310116
# Real params: 2.8406345542623677 0.633671108252816
# Iteration time: 1.46 seconds
# Total time so far: 224.90 seconds
#
# Fitting simulation 122
# Fitted params: 1.9981556160076306 0.20079383303700962
# Real params: 1.9930668116468624 0.20238780542507623
# Iteration time: 1.49 seconds
# Total time so far: 226.39 seconds
#
# Fitting simulation 123
# Fitted params: 2.9039703878407024 0.15514813710078074
# Real params: 2.8267740031684987 0.15920752220346696
# Iteration time: 2.38 seconds
# Total time so far: 228.77 seconds
#
# Fitting simulation 124
# Fitted params: 2.2045456392274705 0.3267515652324214
# Real params: 2.2494952637246857 0.33390610071282817
# Iteration time: 1.67 seconds
# Total time so far: 230.44 seconds
#
# Fitting simulation 125
# Fitted params: 0.4028456920279618 0.11575029940592084
# Real params: 0.4072329236914902 0.11644618450169736
# Iteration time: 1.91 seconds
# Total time so far: 232.35 seconds
#
# Fitting simulation 126
# Fitted params: 0.406826841013537 0.331331113559042
# Real params: 0.4022326935001872 0.32825989710495174
# Iteration time: 1.57 seconds
# Total time so far: 233.92 seconds
#
# Fitting simulation 127
# Fitted params: 2.6095453988805715 0.6242864342639719
# Real params: 2.5748113228242544 0.623485973027733
# Iteration time: 1.08 seconds
# Total time so far: 235.00 seconds
#
# Fitting simulation 128
# Fitted params: 2.365940565748642 0.9345056203566967
# Real params: 2.373345903702978 0.9315391116661924
# Iteration time: 1.53 seconds
# Total time so far: 236.54 seconds
#
# Fitting simulation 129
# Fitted params: 1.6087646078773064 0.42824296453195765
# Real params: 1.600573307065579 0.4295477271662722
# Iteration time: 1.34 seconds
# Total time so far: 237.88 seconds
#
# Fitting simulation 130
# Fitted params: 1.4840883023813003 0.7030457556971049
# Real params: 1.4725102248745614 0.6940768400575699
# Iteration time: 1.04 seconds
# Total time so far: 238.92 seconds
#
# Fitting simulation 131
# Fitted params: 0.948655002034523 0.6968796798785177
# Real params: 0.9487882947623508 0.6968738188692815
# Iteration time: 1.61 seconds
# Total time so far: 240.54 seconds
#
# Fitting simulation 132
# Fitted params: 1.7469551372715129 0.9366053848178899
# Real params: 1.7372685640016772 0.9284716364790996
# Iteration time: 1.25 seconds
# Total time so far: 241.79 seconds
#
# Fitting simulation 133
# Fitted params: 0.8116259187346823 0.4290740571045799
# Real params: 0.7925166548568251 0.4276520482364553
# Iteration time: 1.73 seconds
# Total time so far: 243.53 seconds
#
# Fitting simulation 134
# Fitted params: 2.2092172663501075 0.17727904963093738
# Real params: 2.2821357086392067 0.17628584020844598
# Iteration time: 2.08 seconds
# Total time so far: 245.61 seconds
#
# Fitting simulation 135
# Fitted params: 0.8380231626467115 0.8983452002972306
# Real params: 0.8288132620803899 0.888239139060272
# Iteration time: 2.86 seconds
# Total time so far: 248.47 seconds
#
# Fitting simulation 136
# Fitted params: 2.6630321965420656 0.4562631492191692
# Real params: 2.6222068672638232 0.45312982239873134
# Iteration time: 1.43 seconds
# Total time so far: 249.90 seconds
#
# Fitting simulation 137
# Fitted params: 0.8583181357327109 0.8173327266311035
# Real params: 0.8081364943704845 0.7839481178480406
# Iteration time: 1.31 seconds
# Total time so far: 251.21 seconds
#
# Fitting simulation 138
# Fitted params: 2.7039215348752585 0.992598572418517
# Real params: 2.6616554611202012 0.9927376337178655
# Iteration time: 2.03 seconds
# Total time so far: 253.24 seconds
#
# Fitting simulation 139
# Fitted params: 2.5395358666082952 0.1807422096074291
# Real params: 2.5880112505922535 0.17649958950018843
# Iteration time: 2.04 seconds
# Total time so far: 255.29 seconds
#
# Fitting simulation 140
# Fitted params: 1.1306632539140251 0.40351316500297324
# Real params: 1.1289121400035271 0.40091719003356574
# Iteration time: 1.01 seconds
# Total time so far: 256.30 seconds
#
# Fitting simulation 141
# Fitted params: 0.5892921180508736 0.9755644046553065
# Real params: 0.38696167489095123 0.8068539880272886
# Iteration time: 2.32 seconds
# Total time so far: 258.62 seconds
#
# Fitting simulation 142
# Fitted params: 2.478149594283123 0.5719935662448684
# Real params: 2.473325140961655 0.5628384942872595
# Iteration time: 1.42 seconds
# Total time so far: 260.04 seconds
#
# Fitting simulation 143
# Fitted params: 1.5552270015342453 0.5968622458184634
# Real params: 1.5320167975756638 0.5913236664496885
# Iteration time: 1.66 seconds
# Total time so far: 261.70 seconds
#
# Fitting simulation 144
# Fitted params: 2.5004898077722766 0.4142730900574737
# Real params: 2.492569463848431 0.41082989042025586
# Iteration time: 1.09 seconds
# Total time so far: 262.79 seconds
#
# Fitting simulation 145
# Fitted params: 2.65373274269042 0.5536063622455201
# Real params: 2.631611483090281 0.5567869612124923
# Iteration time: 1.12 seconds
# Total time so far: 263.91 seconds
#
# Fitting simulation 146
# Fitted params: 0.24947042942199765 0.18681698751673773
# Real params: 0.25940228983548397 0.19276113166071412
# Iteration time: 3.08 seconds
# Total time so far: 266.98 seconds
#
# Fitting simulation 147
# Fitted params: 1.7600090465275224 0.4179130321041995
# Real params: 1.7935810811951567 0.40922970173615447
# Iteration time: 1.23 seconds
# Total time so far: 268.21 seconds
#
# Fitting simulation 148
# Fitted params: 2.0188297029496183 0.9812129449809809
# Real params: 2.0106825684458367 0.9870720019625233
# Iteration time: 0.91 seconds
# Total time so far: 269.13 seconds
#
# Fitting simulation 149
# Fitted params: 1.385914599935711 0.4336298174805327
# Real params: 1.4233451790849558 0.4320103651370709
# Iteration time: 1.11 seconds
# Total time so far: 270.23 seconds
#
# Fitting simulation 150
# Fitted params: 0.5373337647652424 0.6755835482051432
# Real params: 0.6026424059855086 0.7323255132210489
# Iteration time: 2.24 seconds
# Total time so far: 272.47 seconds
#
# Fitting simulation 151
# Fitted params: 2.2661100229198667 0.4955931478807668
# Real params: 2.2624367850244815 0.49600699996268804
# Iteration time: 2.82 seconds
# Total time so far: 275.29 seconds
#
# Fitting simulation 152
# Fitted params: 1.2660409014202807 0.13964247510891084
# Real params: 1.282584192227192 0.13772963443865038
# Iteration time: 1.45 seconds
# Total time so far: 276.74 seconds
#
# Fitting simulation 153
# Fitted params: 0.5478948000125917 0.1902298083240483
# Real params: 0.5501967131990663 0.19147170402932467
# Iteration time: 2.22 seconds
# Total time so far: 278.97 seconds
#
# Fitting simulation 154
# Fitted params: 0.7197260138119124 0.5682667120402318
# Real params: 0.7362587578403992 0.5809624269728428
# Iteration time: 2.11 seconds
# Total time so far: 281.07 seconds
#
# Fitting simulation 155
# Fitted params: 1.898053073162583 0.4333838157189973
# Real params: 1.8733517448098933 0.4353526766470641
# Iteration time: 1.07 seconds
# Total time so far: 282.14 seconds
#
# Fitting simulation 156
# Fitted params: 1.6612706720222674 0.11580752124695913
# Real params: 1.7180513501599934 0.11524032473796975
# Iteration time: 1.47 seconds
# Total time so far: 283.61 seconds
#
# Fitting simulation 157
# Fitted params: 1.1240330860802885 0.7373541949820371
# Real params: 1.1075869400651315 0.7315215704468148
# Iteration time: 1.73 seconds
# Total time so far: 285.34 seconds
#
# Fitting simulation 158
# Fitted params: 1.2718381493194713 0.6603636327402944
# Real params: 1.2557874582145667 0.6512946436078986
# Iteration time: 1.88 seconds
# Total time so far: 287.22 seconds
#
# Fitting simulation 159
# Fitted params: 2.4376083685680445 0.5252278352274155
# Real params: 2.4446884924551915 0.5159357673745667
# Iteration time: 1.43 seconds
# Total time so far: 288.65 seconds
#
# Fitting simulation 160
# Fitted params: 0.8660669182737911 0.42683248538188606
# Real params: 0.8674132770632119 0.42303535729367403
# Iteration time: 1.88 seconds
# Total time so far: 290.52 seconds
#
# Fitting simulation 161
# Fitted params: 1.324285169254446 0.6853893167643259
# Real params: 1.345192662154896 0.6884636730732148
# Iteration time: 1.37 seconds
# Total time so far: 291.90 seconds
#
# Fitting simulation 162
# Fitted params: 1.6466893352289218 0.8156127498543151
# Real params: 1.6632681842239505 0.8114298143313745
# Iteration time: 1.14 seconds
# Total time so far: 293.04 seconds
#
# Fitting simulation 163
# Fitted params: 0.2684920075918627 0.9659429320399381
# Real params: 0.14458930972904127 0.8654606406254
# Iteration time: 1.37 seconds
# Total time so far: 294.41 seconds
#
# Fitting simulation 164
# Fitted params: 1.7904068291898854 0.9662208180674048
# Real params: 1.7684412783548846 0.9627625511668723
# Iteration time: 1.70 seconds
# Total time so far: 296.11 seconds
#
# Fitting simulation 165
# Fitted params: 0.802964319618884 0.662612844033596
# Real params: 0.8182084247971595 0.6768653792742949
# Iteration time: 1.69 seconds
# Total time so far: 297.80 seconds
#
# Fitting simulation 166
# Fitted params: 0.12181550866773899 0.11393617194112673
# Real params: 0.11048599913754632 0.10660516385729764
# Iteration time: 1.66 seconds
# Total time so far: 299.47 seconds
#
# Fitting simulation 167
# Fitted params: 1.8264063136167488 0.2996395845593916
# Real params: 1.8624827809773925 0.30063797752806637
# Iteration time: 0.97 seconds
# Total time so far: 300.44 seconds
#
# Fitting simulation 168
# Fitted params: 2.696249999636874 0.17889214918381566
# Real params: 2.6390182173393577 0.1757739926464713
# Iteration time: 1.73 seconds
# Total time so far: 302.17 seconds
#
# Fitting simulation 169
# Fitted params: 1.347569276425001 0.7508604390447629
# Real params: 1.3583310057498639 0.7430299425006771
# Iteration time: 1.57 seconds
# Total time so far: 303.74 seconds
#
# Fitting simulation 170
# Fitted params: 1.511280294329905 0.39459320594749925
# Real params: 1.4910915883994096 0.3904959626914235
# Iteration time: 1.08 seconds
# Total time so far: 304.82 seconds
#
# Fitting simulation 171
# Fitted params: 1.647678452989371 0.5445327751262398
# Real params: 1.6394833204592285 0.5445895659123318
# Iteration time: 1.17 seconds
# Total time so far: 305.98 seconds
#
# Fitting simulation 172
# Fitted params: 2.0052310952269616 0.5732304462173646
# Real params: 2.0136479310492668 0.5692890401688896
# Iteration time: 1.17 seconds
# Total time so far: 307.15 seconds
#
# Fitting simulation 173
# Fitted params: 1.6203430543124724 0.2258310736280615
# Real params: 1.6589125503619055 0.2285223268798051
# Iteration time: 1.17 seconds
# Total time so far: 308.33 seconds
#
# Fitting simulation 174
# Fitted params: 0.7989246152096782 0.10273547008917958
# Real params: 0.8021502058242082 0.10558881528834158
# Iteration time: 1.24 seconds
# Total time so far: 309.57 seconds
#
# Fitting simulation 175
# Fitted params: 0.5234762828941961 0.9686760527404205
# Real params: 0.24412717853576943 0.7285719243222015
# Iteration time: 1.83 seconds
# Total time so far: 311.40 seconds
#
# Fitting simulation 176
# Fitted params: 0.5459981352858765 0.38553779158762147
# Real params: 0.5356203120970876 0.37864162455676476
# Iteration time: 2.16 seconds
# Total time so far: 313.57 seconds
#
# Fitting simulation 177
# Fitted params: 0.9418914954647339 0.9428581986828836
# Real params: 0.8619963818772416 0.8907787373944762
# Iteration time: 2.28 seconds
# Total time so far: 315.85 seconds
#
# Fitting simulation 178
# Fitted params: 1.6524285137425765 0.9315114849609758
# Real params: 1.6561569399253686 0.929777087458754
# Iteration time: 1.88 seconds
# Total time so far: 317.73 seconds
#
# Fitting simulation 179
# Fitted params: 0.8660348808647973 0.894052062166424
# Real params: 0.802615364342081 0.8543438094600371
# Iteration time: 1.87 seconds
# Total time so far: 319.60 seconds
#
# Fitting simulation 180
# Fitted params: 2.4590411717662395 0.39514610343444334
# Real params: 2.533676602814402 0.39537212318972115
# Iteration time: 1.58 seconds
# Total time so far: 321.18 seconds
#
# Fitting simulation 181
# Fitted params: 1.4497377738119215 0.3969468951034925
# Real params: 1.4508199376441173 0.3947014504042886
# Iteration time: 1.03 seconds
# Total time so far: 322.21 seconds
#
# Fitting simulation 182
# Fitted params: 1.7965526327482293 0.1516330317763788
# Real params: 1.7396766994791004 0.15387336737940221
# Iteration time: 1.93 seconds
# Total time so far: 324.15 seconds
#
# Fitting simulation 183
# Fitted params: 1.330155953190034 0.4109269963035005
# Real params: 1.3336371592691911 0.41514932440117047
# Iteration time: 1.17 seconds
# Total time so far: 325.31 seconds
#
# Fitting simulation 184
# Fitted params: 1.3360641626780294 0.5709060716776405
# Real params: 1.3212033199237894 0.573362876062032
# Iteration time: 1.09 seconds
# Total time so far: 326.41 seconds
#
# Fitting simulation 185
# Fitted params: 0.6134068008712023 0.8642761489041029
# Real params: 0.6213387111313479 0.8683225451183395
# Iteration time: 2.19 seconds
# Total time so far: 328.59 seconds
#
# Fitting simulation 186
# Fitted params: 0.6757507981477707 0.43177298023277216
# Real params: 0.6546476228484251 0.42469251253278384
# Iteration time: 1.18 seconds
# Total time so far: 329.78 seconds
#
# Fitting simulation 187
# Fitted params: 0.8230884715521454 0.9315513515535793
# Real params: 0.8737041933581094 0.9627697911168246
# Iteration time: 1.86 seconds
# Total time so far: 331.64 seconds
#
# Fitting simulation 188
# Fitted params: 0.4769211928258523 0.3234736946584384
# Real params: 0.471600331343467 0.32388905770395826
# Iteration time: 3.80 seconds
# Total time so far: 335.44 seconds
#
# Fitting simulation 189
# Fitted params: 2.421479907660362 0.2508404042470212
# Real params: 2.3690900364252805 0.25173395501708346
# Iteration time: 1.23 seconds
# Total time so far: 336.67 seconds
#
# Fitting simulation 190
# Fitted params: 0.1 0.6560624121314984
# Real params: 0.42244956946394263 0.9371565535386093
# Iteration time: 2.63 seconds
# Total time so far: 339.30 seconds
#
# Fitting simulation 191
# Fitted params: 0.926726548638294 0.1936120303710497
# Real params: 0.9378515158310541 0.1922175456738943
# Iteration time: 2.36 seconds
# Total time so far: 341.66 seconds
#
# Fitting simulation 192
# Fitted params: 2.459915074831052 0.9288394319078105
# Real params: 2.4389008595618846 0.9209263335757997
# Iteration time: 0.95 seconds
# Total time so far: 342.61 seconds
#
# Fitting simulation 193
# Fitted params: 2.200988995281203 0.21127861233370404
# Real params: 2.216995101870914 0.2167785749022217
# Iteration time: 2.04 seconds
# Total time so far: 344.64 seconds
#
# Fitting simulation 194
# Fitted params: 1.4606521937670007 0.9140707891954581
# Real params: 1.457120868208312 0.9177976531018582
# Iteration time: 2.07 seconds
# Total time so far: 346.72 seconds
#
# Fitting simulation 195
# Fitted params: 1.0968078674723432 0.37367125802889556
# Real params: 1.0856590332051663 0.3741313434595598
# Iteration time: 1.52 seconds
# Total time so far: 348.23 seconds
#
# Fitting simulation 196
# Fitted params: 0.3173470584671054 0.5864736914020084
# Real params: 0.3515091514745715 0.6170660701958957
# Iteration time: 2.45 seconds
# Total time so far: 350.68 seconds
#
# Fitting simulation 197
# Fitted params: 2.306542103664226 0.49529079747275456
# Real params: 2.336670308482332 0.4997559202844174
# Iteration time: 1.51 seconds
# Total time so far: 352.19 seconds
#
# Fitting simulation 198
# Fitted params: 0.24247997897658286 0.5297568907396456
# Real params: 0.2643594294757703 0.5456130290241439
# Iteration time: 2.88 seconds
# Total time so far: 355.08 seconds
#
# Fitting simulation 199
# Fitted params: 2.6120761057673425 0.6159422460300477
# Real params: 2.575447708084231 0.6200927374434173
# Iteration time: 1.67 seconds
# Total time so far: 356.74 seconds
#
# Fitting simulation 200
# Fitted params: 1.063497097069685 0.8922752234010487
# Real params: 1.044923225050497 0.882577416949631
# Iteration time: 1.39 seconds
# Total time so far: 358.14 seconds
#
# Fitting simulation 201
# Fitted params: 2.2942280452174644 0.5994580105370467
# Real params: 2.263161071792409 0.5951870097787209
# Iteration time: 0.96 seconds
# Total time so far: 359.09 seconds
#
# Fitting simulation 202
# Fitted params: 2.4060223979728423 0.1229238684715215
# Real params: 2.339205652343406 0.12075179852943124
# Iteration time: 3.25 seconds
# Total time so far: 362.34 seconds
#
# Fitting simulation 203
# Fitted params: 2.2179290633152053 0.6568968384110118
# Real params: 2.234058066531342 0.6515032394197741
# Iteration time: 1.93 seconds
# Total time so far: 364.27 seconds
#
# Fitting simulation 204
# Fitted params: 1.3892543054563553 0.7849410954268748
# Real params: 1.362629248771239 0.7818869431939882
# Iteration time: 1.46 seconds
# Total time so far: 365.73 seconds
#
# Fitting simulation 205
# Fitted params: 0.2324872122495114 0.29726426600124384
# Real params: 0.22683677577005013 0.2910357184702843
# Iteration time: 2.33 seconds
# Total time so far: 368.05 seconds
#
# Fitting simulation 206
# Fitted params: 1.0230895214586102 0.5807823647999887
# Real params: 1.0386697855723066 0.5887048423936424
# Iteration time: 1.71 seconds
# Total time so far: 369.77 seconds
#
# Fitting simulation 207
# Fitted params: 2.2845775993805555 0.7731260518709498
# Real params: 2.2758435929872047 0.7719111660572654
# Iteration time: 0.97 seconds
# Total time so far: 370.74 seconds
#
# Fitting simulation 208
# Fitted params: 0.9595009083978627 0.617024780900243
# Real params: 0.9705879325252905 0.6211504222519679
# Iteration time: 1.66 seconds
# Total time so far: 372.40 seconds
#
# Fitting simulation 209
# Fitted params: 1.3831033196461142 0.5369718248400095
# Real params: 1.3722303228512336 0.5317741819280911
# Iteration time: 1.10 seconds
# Total time so far: 373.51 seconds
#
# Fitting simulation 210
# Fitted params: 1.7799651242430576 0.7310108661463107
# Real params: 1.7658426007091192 0.7265104223315885
# Iteration time: 1.69 seconds
# Total time so far: 375.20 seconds
#
# Fitting simulation 211
# Fitted params: 1.8582067407967895 0.3634204098651531
# Real params: 1.879549918669213 0.36500380192083137
# Iteration time: 1.51 seconds
# Total time so far: 376.71 seconds
#
# Fitting simulation 212
# Fitted params: 0.326272969970847 0.9967206974996947
# Real params: 0.11343286671334829 0.8116171752386533
# Iteration time: 1.07 seconds
# Total time so far: 377.78 seconds
#
# Fitting simulation 213
# Fitted params: 2.3995015832017392 0.5008429970369798
# Real params: 2.4134821052781117 0.4995896321382334
# Iteration time: 1.20 seconds
# Total time so far: 378.98 seconds
#
# Fitting simulation 214
# Fitted params: 0.805065801589372 0.3137437723395763
# Real params: 0.8231830584582583 0.31178781458510285
# Iteration time: 1.71 seconds
# Total time so far: 380.69 seconds
#
# Fitting simulation 215
# Fitted params: 1.4070553975243196 0.39207020144526866
# Real params: 1.3849955172379587 0.3941382415948954
# Iteration time: 1.25 seconds
# Total time so far: 381.94 seconds
#
# Fitting simulation 216
# Fitted params: 2.300286430330605 0.3854543014539331
# Real params: 2.3245300341233266 0.38595611740409375
# Iteration time: 1.23 seconds
# Total time so far: 383.17 seconds
#
# Fitting simulation 217
# Fitted params: 2.27424627903399 0.3827096837827521
# Real params: 2.277006969868951 0.38919670871477186
# Iteration time: 2.02 seconds
# Total time so far: 385.20 seconds
#
# Fitting simulation 218
# Fitted params: 2.8661596670946308 0.6068587007543876
# Real params: 2.8904523937883826 0.606617461571478
# Iteration time: 1.38 seconds
# Total time so far: 386.58 seconds
#
# Fitting simulation 219
# Fitted params: 0.9552416411740396 0.7255599140562813
# Real params: 0.9512611823375426 0.7240956409084549
# Iteration time: 0.82 seconds
# Total time so far: 387.40 seconds
#
# Fitting simulation 220
# Fitted params: 1.8853830039349035 0.23185268650389837
# Real params: 1.9479354387429613 0.2334261170362686
# Iteration time: 1.32 seconds
# Total time so far: 388.72 seconds
#
# Fitting simulation 221
# Fitted params: 2.4307922897022083 0.3385672971814815
# Real params: 2.4471473508876893 0.3437594784404355
# Iteration time: 1.68 seconds
# Total time so far: 390.40 seconds
#
# Fitting simulation 222
# Fitted params: 1.2834304120123492 0.1625606033760873
# Real params: 1.3121977290690197 0.1612646093068157
# Iteration time: 1.42 seconds
# Total time so far: 391.82 seconds
#
# Fitting simulation 223
# Fitted params: 0.8498500086860327 0.1381217340588492
# Real params: 0.8478063355700501 0.1364936500341276
# Iteration time: 1.66 seconds
# Total time so far: 393.49 seconds
#
# Fitting simulation 224
# Fitted params: 1.6538931550100497 0.34218411617590216
# Real params: 1.6783462773442275 0.34074497333080267
# Iteration time: 1.29 seconds
# Total time so far: 394.78 seconds
#
# Fitting simulation 225
# Fitted params: 1.847956794056047 0.7603791117422897
# Real params: 1.856060383896203 0.7641197273734686
# Iteration time: 1.40 seconds
# Total time so far: 396.17 seconds
#
# Fitting simulation 226
# Fitted params: 0.3035609546107363 0.9209895661865327
# Real params: 0.3427960536563636 0.9499028675052283
# Iteration time: 1.21 seconds
# Total time so far: 397.38 seconds
#
# Fitting simulation 227
# Fitted params: 1.923693287001718 0.8293607654186926
# Real params: 1.9171182821703097 0.82311096516297
# Iteration time: 1.16 seconds
# Total time so far: 398.55 seconds
#
# Fitting simulation 228
# Fitted params: 2.0705980666547905 0.8097546007627268
# Real params: 2.07481770878926 0.8087919001261837
# Iteration time: 0.90 seconds
# Total time so far: 399.44 seconds
#
# Fitting simulation 229
# Fitted params: 2.57087856956939 0.8142282100174579
# Real params: 2.569067096559017 0.8083990608663301
# Iteration time: 1.89 seconds
# Total time so far: 401.33 seconds
#
# Fitting simulation 230
# Fitted params: 0.591977754193793 0.6639968980818226
# Real params: 0.5619990131945743 0.6356080100248734
# Iteration time: 1.88 seconds
# Total time so far: 403.22 seconds
#
# Fitting simulation 231
# Fitted params: 1.75035332284059 0.19518178453989862
# Real params: 1.7722351138629162 0.1952542676147675
# Iteration time: 1.18 seconds
# Total time so far: 404.39 seconds
#
# Fitting simulation 232
# Fitted params: 1.4283425626829243 0.34499875271965236
# Real params: 1.4387936901145397 0.34200852227614936
# Iteration time: 0.95 seconds
# Total time so far: 405.34 seconds
#
# Fitting simulation 233
# Fitted params: 0.5135345370782671 0.27281953029562483
# Real params: 0.5218996838378545 0.2783036229330245
# Iteration time: 2.64 seconds
# Total time so far: 407.99 seconds
#
# Fitting simulation 234
# Fitted params: 1.4617969593807705 0.9141613756500768
# Real params: 1.4662484615763884 0.9149648796556271
# Iteration time: 1.33 seconds
# Total time so far: 409.32 seconds
#
# Fitting simulation 235
# Fitted params: 2.09707347600324 0.32346592559730875
# Real params: 2.1294024321619682 0.33138496984080074
# Iteration time: 1.06 seconds
# Total time so far: 410.38 seconds
#
# Fitting simulation 236
# Fitted params: 2.80519133020818 0.5382573360591656
# Real params: 2.840855101360172 0.5380923896451624
# Iteration time: 1.04 seconds
# Total time so far: 411.42 seconds
#
# Fitting simulation 237
# Fitted params: 2.818076836555563 0.8743761042165504
# Real params: 2.8074201167336295 0.8733615544847487
# Iteration time: 1.15 seconds
# Total time so far: 412.57 seconds
#
# Fitting simulation 238
# Fitted params: 2.225767559989761 0.8082706225751369
# Real params: 2.235772701222841 0.811395240870986
# Iteration time: 1.23 seconds
# Total time so far: 413.80 seconds
#
# Fitting simulation 239
# Fitted params: 0.6377184855846469 0.508373758896332
# Real params: 0.6349811340875541 0.5030238321446663
# Iteration time: 1.88 seconds
# Total time so far: 415.68 seconds
#
# Fitting simulation 240
# Fitted params: 2.8797943318966945 0.6728494305123561
# Real params: 2.86769794064059 0.6688139702611469
# Iteration time: 0.96 seconds
# Total time so far: 416.64 seconds
#
# Fitting simulation 241
# Fitted params: 1.1979070333615816 0.25534599808766983
# Real params: 1.2023073962758315 0.2537134334307683
# Iteration time: 1.18 seconds
# Total time so far: 417.82 seconds
#
# Fitting simulation 242
# Fitted params: 2.673102145235167 0.43066878395573327
# Real params: 2.639155863860048 0.4253009382585927
# Iteration time: 1.39 seconds
# Total time so far: 419.22 seconds
#
# Fitting simulation 243
# Fitted params: 2.52567448402055 0.35460851980151115
# Real params: 2.4500523303876047 0.35957875084879154
# Iteration time: 1.20 seconds
# Total time so far: 420.42 seconds
#
# Fitting simulation 244
# Fitted params: 2.3532000764609524 0.5964681087119886
# Real params: 2.324333912653422 0.6019846480634536
# Iteration time: 1.09 seconds
# Total time so far: 421.51 seconds
#
# Fitting simulation 245
# Fitted params: 0.6450729997443558 0.11270661130509575
# Real params: 0.6526035328141854 0.10948194209649038
# Iteration time: 1.78 seconds
# Total time so far: 423.28 seconds
#
# Fitting simulation 246
# Fitted params: 1.7237523726732413 0.556629205668774
# Real params: 1.7261275605533435 0.5488495053457534
# Iteration time: 1.25 seconds
# Total time so far: 424.54 seconds
#
# Fitting simulation 247
# Fitted params: 2.292275862712389 0.17119274173095178
# Real params: 2.3305926216184036 0.1700928784857655
# Iteration time: 1.39 seconds
# Total time so far: 425.93 seconds
#
# Fitting simulation 248
# Fitted params: 1.9693604441242025 0.38493610508546616
# Real params: 1.9551036048384998 0.3902623292973575
# Iteration time: 1.75 seconds
# Total time so far: 427.68 seconds
#
# Fitting simulation 249
# Fitted params: 1.709116959853306 0.8360305602814451
# Real params: 1.711267628282755 0.8408876820796003
# Iteration time: 0.98 seconds
# Total time so far: 428.66 seconds
#
# Fitting simulation 250
# Fitted params: 2.17488397289312 0.7971576654096827
# Real params: 2.200383868558723 0.8027772243408545
# Iteration time: 1.28 seconds
# Total time so far: 429.94 seconds
#
# Fitting simulation 251
# Fitted params: 1.3564135544111233 0.43415092565218655
# Real params: 1.3531025482492962 0.43423898318276266
# Iteration time: 1.17 seconds
# Total time so far: 431.10 seconds
#
# Fitting simulation 252
# Fitted params: 0.3527957399209108 0.7718005851677157
# ...
# Fitted params: 1.7682904550507517 0.1161726009479731
# Real params: 1.6917311244735393 0.114989056838975
# Iteration time: 2.24 seconds
# Total time so far: 1522.68 seconds
#
# Fitting simulation 918
# Fitted params: 1.9856521099214741 0.23981317244381073
# Real params: 2.0565651226834536 0.23446891112800777
# Iteration time: 1.16 seconds
# Total time so far: 1523.84 seconds
#
# Fitting simulation 919
# Fitted params: 2.0462362099675175 0.4830530221240934
# Real params: 2.0445843029237407 0.4824802842163033
# Iteration time: 1.02 seconds
# Total time so far: 1524.86 seconds
#
# Fitting simulation 920
# Fitted params: 1.095425938120166 0.873447190219208
# Real params: 1.056430855790461 0.8541575154121288
# Iteration time: 0.98 seconds
# Total time so far: 1525.84 seconds
#
# Fitting simulation 921
# Fitted params: 0.2641602824912375 0.999354525244665
# Real params: 0.14248311092720803 0.888198339200603
# Iteration time: 0.91 seconds
# Total time so far: 1526.76 seconds
#
# Fitting simulation 922
# Fitted params: 0.4342581528189982 0.9575185605809007
# Real params: 0.13854245028931386 0.6969412163601287
# Iteration time: 1.82 seconds
# Total time so far: 1528.57 seconds
#
# Fitting simulation 923
# Fitted params: 0.2976314252225987 0.7298749899173427
# Real params: 0.4901239276386351 0.893556413200331
# Iteration time: 2.15 seconds
# Total time so far: 1530.72 seconds
#
# Fitting simulation 924
# Fitted params: 0.9518149502690937 0.21770215843459914
# Real params: 0.9517638945742434 0.21978549743740694
# Iteration time: 1.73 seconds
# Total time so far: 1532.46 seconds
#
# Fitting simulation 925
# Fitted params: 1.776998986428017 0.9799300172640909
# Real params: 1.7828972591191437 0.9856971104609744
# Iteration time: 0.92 seconds
# Total time so far: 1533.38 seconds
#
# Fitting simulation 926
# Fitted params: 2.378327203053305 0.4750270316045907
# Real params: 2.4080822563760895 0.4825586385112104
# Iteration time: 1.49 seconds
# Total time so far: 1534.87 seconds
#
# Fitting simulation 927
# Fitted params: 1.8077005413705383 0.9476192936305248
# Real params: 1.8082255979885218 0.951633317208641
# Iteration time: 1.48 seconds
# Total time so far: 1536.35 seconds
#
# Fitting simulation 928
# Fitted params: 1.697444749390302 0.2863739286482817
# Real params: 1.705112158519788 0.2828021767328694
# Iteration time: 1.72 seconds
# Total time so far: 1538.07 seconds
#
# Fitting simulation 929
# Fitted params: 2.9498488470885778 0.950194251016434
# Real params: 2.9342679703656156 0.948733009108107
# Iteration time: 1.28 seconds
# Total time so far: 1539.35 seconds
#
# Fitting simulation 930
# Fitted params: 0.6179357885225022 0.8656795474595205
# Real params: 0.6368153182407512 0.8877620119525276
# Iteration time: 1.41 seconds
# Total time so far: 1540.76 seconds
#
# Fitting simulation 931
# Fitted params: 0.9657535559069158 0.19208187899316104
# Real params: 0.966728887517823 0.19064795565263187
# Iteration time: 2.37 seconds
# Total time so far: 1543.12 seconds
#
# Fitting simulation 932
# Fitted params: 0.1905644441291174 0.37061986195362717
# Real params: 0.2868691141028076 0.4480491329129922
# Iteration time: 2.35 seconds
# Total time so far: 1545.47 seconds
#
# Fitting simulation 933
# Fitted params: 1.1757986430520229 0.9699930012945754
# Real params: 1.1733572670661219 0.9684752627049181
# Iteration time: 1.29 seconds
# Total time so far: 1546.76 seconds
#
# Fitting simulation 934
# Fitted params: 0.21476907637057108 0.19265693802650835
# Real params: 0.2210926666190564 0.19926813290861894
# Iteration time: 2.54 seconds
# Total time so far: 1549.30 seconds
#
# Fitting simulation 935
# Fitted params: 1.1117362531623411 0.16410219453585928
# Real params: 1.0905551574796237 0.16263292018723824
# Iteration time: 1.10 seconds
# Total time so far: 1550.40 seconds
#
# Fitting simulation 936
# Fitted params: 2.331726394352771 0.7271309718863239
# Real params: 2.3063248480926952 0.7222628864817641
# Iteration time: 1.04 seconds
# Total time so far: 1551.44 seconds
#
# Fitting simulation 937
# Fitted params: 1.5553224494840596 0.4728046608598843
# Real params: 1.5510572716869833 0.47501685847422326
# Iteration time: 1.69 seconds
# Total time so far: 1553.12 seconds
#
# Fitting simulation 938
# Fitted params: 1.9884656392675522 1.0
# Real params: 1.9765034821507343 0.9990360182208496
# Iteration time: 1.05 seconds
# Total time so far: 1554.18 seconds
#
# Fitting simulation 939
# Fitted params: 0.7818865755337758 0.12947370976430225
# Real params: 0.7842456529889946 0.13048868712531295
# Iteration time: 2.86 seconds
# Total time so far: 1557.04 seconds
#
# Fitting simulation 940
# Fitted params: 2.346253595347159 0.2645842724313417
# Real params: 2.3302772861632004 0.2689592098213286
# Iteration time: 0.91 seconds
# Total time so far: 1557.95 seconds
#
# Fitting simulation 941
# Fitted params: 2.9669642285387683 0.47911976301491577
# Real params: 2.9950921469121523 0.46877789719135454
# Iteration time: 1.07 seconds
# Total time so far: 1559.02 seconds
#
# Fitting simulation 942
# Fitted params: 1.4230701805595152 0.8574447131544438
# Real params: 1.419384920439732 0.8538741876266741
# Iteration time: 2.19 seconds
# Total time so far: 1561.22 seconds
#
# Fitting simulation 943
# Fitted params: 2.6935716719776384 0.2703492827351374
# Real params: 2.6423461878629997 0.2709967432197513
# Iteration time: 1.58 seconds
# Total time so far: 1562.80 seconds
#
# Fitting simulation 944
# Fitted params: 2.0365131844856372 0.5548416502446283
# Real params: 2.0282016333377952 0.5541386711204731
# Iteration time: 1.31 seconds
# Total time so far: 1564.11 seconds
#
# Fitting simulation 945
# Fitted params: 1.3898759413963278 0.5839046858411371
# Real params: 1.3892655373852953 0.5823653210753038
# Iteration time: 1.17 seconds
# Total time so far: 1565.28 seconds
#
# Fitting simulation 946
# Fitted params: 1.896606314399915 0.46746013049548263
# Real params: 1.914032043713502 0.4718364484603983
# Iteration time: 0.89 seconds
# Total time so far: 1566.17 seconds
#
# Fitting simulation 947
# Fitted params: 0.9989832465139169 0.20784111211535056
# Real params: 0.9936135479527688 0.21082187745415873
# Iteration time: 1.80 seconds
# Total time so far: 1567.97 seconds
#
# Fitting simulation 948
# Fitted params: 2.105061478914239 0.32092494200746846
# Real params: 2.176655300811382 0.323114998762999
# Iteration time: 1.37 seconds
# Total time so far: 1569.33 seconds
#
# Fitting simulation 949
# Fitted params: 0.6971916280104387 0.35145746396614524
# Real params: 0.7025799644719257 0.3460186998035335
# Iteration time: 1.24 seconds
# Total time so far: 1570.58 seconds
#
# Fitting simulation 950
# Fitted params: 1.8229375753397437 0.9575515212330074
# Real params: 1.8413508582111136 0.9685401608760492
# Iteration time: 1.63 seconds
# Total time so far: 1572.21 seconds
#
# Fitting simulation 951
# Fitted params: 2.2815461642993964 0.4955354350291625
# Real params: 2.279534532153037 0.4912334592646276
# Iteration time: 1.62 seconds
# Total time so far: 1573.83 seconds
#
# Fitting simulation 952
# Fitted params: 1.5663082928026488 0.4780592611951699
# Real params: 1.570205930844136 0.47901049355731296
# Iteration time: 0.80 seconds
# Total time so far: 1574.64 seconds
#
# Fitting simulation 953
# Fitted params: 0.44625383132430757 0.5081300668419427
# Real params: 0.49434719735564736 0.5466073147255561
# Iteration time: 1.86 seconds
# Total time so far: 1576.50 seconds
#
# Fitting simulation 954
# Fitted params: 2.0918119415420353 0.444925389283011
# Real params: 2.0702848170258763 0.45328754282628014
# Iteration time: 1.30 seconds
# Total time so far: 1577.80 seconds
#
# Fitting simulation 955
# Fitted params: 0.9788467509983252 0.98013750816681
# Real params: 0.9736000077335981 0.9797642545202547
# Iteration time: 1.61 seconds
# Total time so far: 1579.41 seconds
#
# Fitting simulation 956
# Fitted params: 0.9335763468566485 0.9361271005926883
# Real params: 0.9448088343498905 0.9492876059327042
# Iteration time: 1.75 seconds
# Total time so far: 1581.16 seconds
#
# Fitting simulation 957
# Fitted params: 1.5291702632912854 0.39830080926873485
# Real params: 1.5368675328894668 0.39782561594808974
# Iteration time: 1.50 seconds
# Total time so far: 1582.66 seconds
#
# Fitting simulation 958
# Fitted params: 1.0400340608147833 0.737344173295329
# Real params: 1.040581050284896 0.7446429887258198
# Iteration time: 1.07 seconds
# Total time so far: 1583.73 seconds
#
# Fitting simulation 959
# Fitted params: 0.8168510510913847 0.20700610923036228
# Real params: 0.7960044174701079 0.20023531417608176
# Iteration time: 1.32 seconds
# Total time so far: 1585.05 seconds
#
# Fitting simulation 960
# Fitted params: 0.31835332916529796 0.1435869857776155
# Real params: 0.3237007335932363 0.14284819356438616
# Iteration time: 1.54 seconds
# Total time so far: 1586.59 seconds
#
# Fitting simulation 961
# Fitted params: 1.865136064520939 0.8927079503424666
# Real params: 1.8885846484499738 0.8997401145062766
# Iteration time: 1.22 seconds
# Total time so far: 1587.81 seconds
#
# Fitting simulation 962
# Fitted params: 1.2440528623244462 0.6779251948578765
# Real params: 1.224681157302141 0.6687103016476018
# Iteration time: 1.23 seconds
# Total time so far: 1589.03 seconds
#
# Fitting simulation 963
# Fitted params: 0.4978257271185727 0.25641797612011086
# Real params: 0.5077874349586233 0.26096679953779245
# Iteration time: 2.60 seconds
# Total time so far: 1591.64 seconds
#
# Fitting simulation 964
# Fitted params: 0.8241249619576633 0.9833463228940811
# Real params: 0.8305624252065129 0.9856606195550464
# Iteration time: 1.85 seconds
# Total time so far: 1593.48 seconds
#
# Fitting simulation 965
# Fitted params: 1.1576031304815053 0.7873595593403293
# Real params: 1.160219244339177 0.7920011007628226
# Iteration time: 1.72 seconds
# Total time so far: 1595.20 seconds
#
# Fitting simulation 966
# Fitted params: 2.2591927542826324 0.9684085787093958
# Real params: 2.252444912981719 0.9672933328205087
# Iteration time: 1.14 seconds
# Total time so far: 1596.33 seconds
#
# Fitting simulation 967
# Fitted params: 2.2852241059990623 0.8862132710904765
# Real params: 2.2781950819504027 0.8834878566740014
# Iteration time: 1.18 seconds
# Total time so far: 1597.51 seconds
#
# Fitting simulation 968
# Fitted params: 1.805853231062501 0.5581347981387987
# Real params: 1.8034199532005415 0.559605466664156
# Iteration time: 0.77 seconds
# Total time so far: 1598.28 seconds
#
# Fitting simulation 969
# Fitted params: 0.5451571068877121 0.7325382584610272
# Real params: 0.48573765381761935 0.6845244465182201
# Iteration time: 1.39 seconds
# Total time so far: 1599.67 seconds
#
# Fitting simulation 970
# Fitted params: 0.3617722689921726 0.12929037055097267
# Real params: 0.3506345317301127 0.12999116626307855
# Iteration time: 2.18 seconds
# Total time so far: 1601.85 seconds
#
# Fitting simulation 971
# Fitted params: 0.8769389565030791 0.21040548133425085
# Real params: 0.8893365856963223 0.20723889198135997
# Iteration time: 1.21 seconds
# Total time so far: 1603.07 seconds
#
# Fitting simulation 972
# Fitted params: 1.7110976876496187 0.4096518756024708
# Real params: 1.700115653764954 0.4045614453748012
# Iteration time: 1.12 seconds
# Total time so far: 1604.19 seconds
#
# Fitting simulation 973
# Fitted params: 0.8926601558182369 0.5692556395915032
# Real params: 0.8961792957472894 0.5678727430028243
# Iteration time: 1.75 seconds
# Total time so far: 1605.94 seconds
#
# Fitting simulation 974
# Fitted params: 0.17428693671846676 0.623024596805964
# Real params: 0.2307625603343197 0.6722143867199079
# Iteration time: 2.71 seconds
# Total time so far: 1608.65 seconds
#
# Fitting simulation 975
# Fitted params: 0.5765715813076379 0.9539561834966142
# Real params: 0.2831301534414856 0.7061759026997841
# Iteration time: 1.73 seconds
# Total time so far: 1610.38 seconds
#
# Fitting simulation 976
# Fitted params: 1.0907826287823892 0.2996878319745273
# Real params: 1.0966272278395337 0.29988303156062524
# Iteration time: 1.82 seconds
# Total time so far: 1612.21 seconds
#
# Fitting simulation 977
# Fitted params: 0.8738457312560285 0.7380582635406384
# Real params: 0.8303511839516785 0.7116574959896409
# Iteration time: 1.40 seconds
# Total time so far: 1613.61 seconds
#
# Fitting simulation 978
# Fitted params: 0.714891310227087 0.7432777720683277
# Real params: 0.6373430862701601 0.691151746264855
# Iteration time: 1.40 seconds
# Total time so far: 1615.01 seconds
#
# Fitting simulation 979
# Fitted params: 1.347054696147995 0.7329061288359578
# Real params: 1.324132321764331 0.726912826095943
# Iteration time: 1.00 seconds
# Total time so far: 1616.01 seconds
#
# Fitting simulation 980
# Fitted params: 1.7210386362085868 0.2636903143569295
# Real params: 1.7550140312365201 0.2645761126983353
# Iteration time: 1.32 seconds
# Total time so far: 1617.33 seconds
#
# Fitting simulation 981
# Fitted params: 1.1213742687842647 0.5951961367234353
# Real params: 1.1056042085681992 0.58613661332741
# Iteration time: 1.34 seconds
# Total time so far: 1618.67 seconds
#
# Fitting simulation 982
# Fitted params: 1.8739805602216126 0.4876525346868768
# Real params: 1.8696390233211082 0.48506043519401354
# Iteration time: 0.82 seconds
# Total time so far: 1619.49 seconds
#
# Fitting simulation 983
# Fitted params: 0.9145959181013953 0.12145904164710473
# Real params: 0.9240068506020899 0.12495564980169807
# Iteration time: 1.91 seconds
# Total time so far: 1621.40 seconds
#
# Fitting simulation 984
# Fitted params: 2.3491473743115394 0.16460500834560046
# Real params: 2.4470203893141163 0.16155692797076773
# Iteration time: 1.10 seconds
# Total time so far: 1622.50 seconds
#
# Fitting simulation 985
# Fitted params: 0.4720209225456891 0.22311062967039888
# Real params: 0.47063694410611745 0.22163802956979073
# Iteration time: 1.55 seconds
# Total time so far: 1624.05 seconds
#
# Fitting simulation 986
# Fitted params: 0.6505749181807475 0.1258942331177987
# Real params: 0.6496692339532382 0.12902313852866412
# Iteration time: 1.48 seconds
# Total time so far: 1625.53 seconds
#
# Fitting simulation 987
# Fitted params: 0.3399881828356341 1.0
# Real params: 0.32583757594053997 0.9892740429265943
# Iteration time: 1.17 seconds
# Total time so far: 1626.70 seconds
#
# Fitting simulation 988
# Fitted params: 2.240870472307093 0.5422871971038355
# Real params: 2.23724082759134 0.5398606039046197
# Iteration time: 1.16 seconds
# Total time so far: 1627.86 seconds
#
# Fitting simulation 989
# Fitted params: 1.5833990900642418 0.1386224977023199
# Real params: 1.5643365287917224 0.13940450862796272
# Iteration time: 1.76 seconds
# Total time so far: 1629.62 seconds
#
# Fitting simulation 990
# Fitted params: 2.238066501916641 0.33766796988049536
# Real params: 2.2509200589865133 0.33887014064879145
# Iteration time: 1.16 seconds
# Total time so far: 1630.78 seconds
#
# Fitting simulation 991
# Fitted params: 0.5035989549226061 0.1423571923099856
# Real params: 0.5338482915084867 0.1467940839119326
# Iteration time: 2.42 seconds
# Total time so far: 1633.20 seconds
#
# Fitting simulation 992
# Fitted params: 2.545675731630013 0.42932538719079616
# Real params: 2.5652211015768667 0.4368840401278321
# Iteration time: 1.27 seconds
# Total time so far: 1634.47 seconds
#
# Fitting simulation 993
# Fitted params: 0.573219970162971 0.14816061728878646
# Real params: 0.6002661158661663 0.1499581440590903
# Iteration time: 1.57 seconds
# Total time so far: 1636.04 seconds
#
# Fitting simulation 994
# Fitted params: 0.5986659490278808 0.6292203441316762
# Real params: 0.581381155680606 0.6189262730745555
# Iteration time: 1.22 seconds
# Total time so far: 1637.26 seconds
#
# Fitting simulation 995
# Fitted params: 1.588600228829127 0.7687832298491066
# Real params: 1.5454813372614837 0.7524696303952393
# Iteration time: 0.89 seconds
# Total time so far: 1638.14 seconds
#
# Fitting simulation 996
# Fitted params: 3.0 0.6875777499287667
# Real params: 2.9658615216649755 0.6890442727200192
# Iteration time: 1.00 seconds
# Total time so far: 1639.14 seconds
#
# Fitting simulation 997
# Fitted params: 2.0783756321539073 0.9066065916052892
# Real params: 2.0807150599421878 0.9128723630352444
# Iteration time: 1.03 seconds
# Total time so far: 1640.18 seconds
#
# Fitting simulation 998
# Fitted params: 2.0190755390147377 0.5295571358902019
# Real params: 2.033324759694538 0.5324279429222724
# Iteration time: 1.20 seconds
# Total time so far: 1641.37 seconds
#
# Fitting simulation 999
# Fitted params: 0.26244504983946665 0.5814078516755635
# Real params: 0.10008908465160901 0.446911161640262
# Iteration time: 2.02 seconds
# Total time so far: 1643.39 seconds
#
#
# Final total time elapsed: 1643.39 seconds
# CPU times: user 27min 22s, sys: 1.95 s, total: 27min 24s
# Wall time: 27min 23s

# %%
y_pred = np.array(y_pred)

from sklearn.metrics import r2_score

r2_combined = r2_score(y_test, y_pred, multioutput='uniform_average')

print(f"Combined R2Score for beta and gamma: {r2_combined}")
# Out:
# Combined R2Score for beta and gamma: 0.9869124020371907

# %% [markdown]
# # Saving parameters obtained

# %%
# Save Params fitted
with open(f'{data_path}/test/sir_params_fit_traditional_noise.pkl', 'wb') as f:
    pkl.dump(y_pred, f)

# %% [markdown]
# # Visual examples: estimated parameters vs real parameters.

# %%
import matplotlib.pyplot as plt

# Example: simulation index to visualize
n_sim = 36

# True parameters
beta_real, gamma_real = y_test[n_sim]
# Estimated parameters
beta_pred, gamma_pred = y_pred[n_sim]

# Simulate using real and predicted parameters
solution_real_fit = simulate_SIR(beta_real, gamma_real)
solution_pred_fit = simulate_SIR(beta_pred, gamma_pred)

# Extract infected curves
I_real_model = solution_real_fit  # simulate_SIR returns only I
I_pred_model = solution_pred_fit
I_data = X_test[n_sim, :]  # Infected values from simulation (ground truth)

# Time vector (assume same as in model)
t = np.linspace(0, 100, len(I_data))
n_points = min(len(t), 1000)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(t[:n_points], I_pred_model[:n_points], '-', label='Predicted params (simulated I)', linewidth=2)
plt.plot(t[:n_points], I_real_model[:n_points], '-', label='Real params (simulated I)', linewidth=2)
plt.plot(t[:n_points], I_data[:n_points], '--', label='Original infected data', alpha=0.7)
plt.xlabel('Time (days)')
plt.ylabel('Number of Infected')
plt.title(f'SIR Model Fit vs Real - Simulation #{n_sim}')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparison: $\beta_{real}$ vs $\beta_{pred}$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Extract beta from predictions and true values
beta_real = y_test[:, 0]
beta_pred = y_pred[:, 0]

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(beta_real, beta_pred, alpha=0.6, label='Samples')
plt.plot([beta_real.min(), beta_real.max()], [beta_real.min(), beta_real.max()], 'r--', label='Perfect prediction')
plt.xlabel('True β (beta_real)')
plt.ylabel('Predicted β (beta_pred)')
plt.title('True vs Predicted β')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparison: $\gamma_{real}$ vs $\gamma_{pred}$

# %%
import matplotlib.pyplot as plt

# Extract gamma from predictions and true values
gamma_real = y_test[:, 1]
gamma_pred = y_pred[:, 1]

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(gamma_real, gamma_pred, alpha=0.6, label='Samples')
plt.plot([gamma_real.min(), gamma_real.max()],
         [gamma_real.min(), gamma_real.max()], 'r--', label='Perfect prediction')
plt.xlabel('True γ (gamma_real)')
plt.ylabel('Predicted γ (gamma_pred)')
plt.title('True vs Predicted γ')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
